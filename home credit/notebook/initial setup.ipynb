# %%
# !pip install kaggle

# %%
# !mkdir .kaggle
# Out:
# mkdir: cannot create directory ‘.kaggle’: File exists

# %%
import json

token = {"username":"sownan","key":"c21620b827cc38362ed399ac8382941b"}

with open('/content/.kaggle/kaggle.json', 'w') as file:
    json.dump(token, file)

# %%
# !chmod 600 /content/.kaggle/kaggle.json

# %%
# !cp /content/.kaggle/kaggle.json ~/.kaggle/kaggle.json

# %%
# !kaggle config set -n path -v{/content}
# Out:
# - path is now set to: {/content}

# %%
# !kaggle competitions download -c home-credit-default-risk -p /content
# Out:
# ...
#   0% 0.00/117k [00:00<?, ?B/s]
# 100% 117k/117k [00:00<00:00, 45.4MB/s]
# ...
#  86% 5.00M/5.81M [00:00<00:00, 9.38MB/s]
# 100% 5.81M/5.81M [00:00<00:00, 10.8MB/s]
# ...
#  72% 26.0M/36.1M [00:01<00:01, 9.25MB/s]
# 100% 36.1M/36.1M [00:01<00:00, 22.3MB/s]
# ...
# 100% 36.8M/36.8M [00:01<00:00, 11.3MB/s]
#
# ...
#  86% 49.0M/56.8M [00:01<00:00, 21.3MB/s]
# 100% 56.8M/56.8M [00:01<00:00, 30.9MB/s]
# ...
#  96% 73.0M/76.3M [00:02<00:00, 24.7MB/s]
# 100% 76.3M/76.3M [00:02<00:00, 31.2MB/s]
# ...
#  84% 81.0M/96.7M [00:03<00:01, 14.6MB/s]
# 100% 96.7M/96.7M [00:03<00:00, 28.3MB/s]
# ...
#  91% 99.0M/109M [00:01<00:00, 64.4MB/s]
# 100% 109M/109M [00:01<00:00, 69.9MB/s]
# ...
#  95% 257M/271M [00:03<00:00, 103MB/s]
# 100% 271M/271M [00:03<00:00, 88.7MB/s]
# ...
#   0% 0.00/36.5k [00:00<?, ?B/s]
# 100% 36.5k/36.5k [00:00<00:00, 30.5MB/s]

# %%
# !unzip \*.zip
# Out:
# Archive:  credit_card_balance.csv.zip
#   inflating: credit_card_balance.csv
#
# Archive:  installments_payments.csv.zip
#   inflating: installments_payments.csv
#
# Archive:  POS_CASH_balance.csv.zip
#   inflating: POS_CASH_balance.csv
#
# Archive:  bureau.csv.zip
#   inflating: bureau.csv
#
# Archive:  application_test.csv.zip
#   inflating: application_test.csv
#
# Archive:  previous_application.csv.zip
#   inflating: previous_application.csv
#
# Archive:  sample_submission.csv.zip
#   inflating: sample_submission.csv
#
# Archive:  application_train.csv.zip
#   inflating: application_train.csv
#
# Archive:  bureau_balance.csv.zip
#   inflating: bureau_balance.csv
#
# 9 archives were successfully processed.

# %%
# Saving requirement
# Install the PyDrive wrapper & import libraries.
# This only needs to be done once in a notebook.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once in a notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
#from google.colab import files
#df_model = pd.DataFrame(df_result)
#df_model.to_csv('df_model.csv')
# Create & upload a file.
uploaded = drive.CreateFile({'title': 'data.csv'})
uploaded.SetContentFile('data.csv')
uploaded.Upload()
#print('Uploaded file with ID {}'.format(uploaded.get('id')))

# %% [markdown]
# # 2

# %%
# connecting google drive with google colab
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install kaggle

# %%
# !mkdir .kaggle

# %%
import json

token = {"username":"sownan","key":"c21620b827cc38362ed399ac8382941b"}

with open('drive/My Drive/Kaggle/kaggle.json', 'w') as file:
    json.dump(token, file)

# %%
# !chmod 600 'drive/My Drive/Kaggle/kaggle.json'

# %%
# !cp 'drive/My Drive/Kaggle/kaggle.json' ~/.kaggle/kaggle.json

# %%
# !kaggle config set -n path -v{/content}
# Out:
# - path is now set to: {/content}

# %%
# !kaggle datasets download --force zalando-research/fashionmnist
# Out:
# ...
#  71% 49.0M/68.8M [00:00<00:00, 135MB/s]
# 100% 68.8M/68.8M [00:00<00:00, 155MB/s]

# %%
# !unzip {/content}/datasets/zalando-research/fashionmnist/fashionmnist.zip
# Out:
# Archive:  {/content}/datasets/zalando-research/fashionmnist/fashionmnist.zip
#   inflating: t10k-images-idx3-ubyte
#   inflating: fashion-mnist_test.csv
#   inflating: train-labels-idx1-ubyte
#   inflating: train-images-idx3-ubyte
#   inflating: fashion-mnist_train.csv
#   inflating: t10k-labels-idx1-ubyte

# %%
# Saving requirement
# Install the PyDrive wrapper & import libraries.
# This only needs to be done once in a notebook.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once in a notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
#from google.colab import files
#df_model = pd.DataFrame(df_result)
#df_model.to_csv('df_model.csv')
# Create & upload a file.
uploaded = drive.CreateFile({'title': 'fashion-mnist_test.csv'})
uploaded.SetContentFile('fashion-mnist_test.csv')
uploaded.Upload()
#print('Uploaded file with ID {}'.format(uploaded.get('id')))

# %%
#from google.colab import files
#df_model = pd.DataFrame(df_result)
#df_model.to_csv('df_model.csv')
# Create & upload a file.
uploaded = drive.CreateFile({'title': 'fashion-mnist_train.csv'})
uploaded.SetContentFile('fashion-mnist_train.csv')
uploaded.Upload()
#print('Uploaded file with ID {}'.format(uploaded.get('id')))
